# %%
import pandas as pd
#from pandas.api.types import CategoricalDtype
from joypy import joyplot
import matplotlib.pyplot as plt

# %%
medium=pd.read_csv(r'medium_data.csv',usecols=['title','claps','reading_time','publication','date'])

# %%
medium.head(3)
# Out:
#                                                title  claps  reading_time  \
# 0  A Beginner’s Guide to Word Embedding with Gens...    850             8
# 1  Hands-on Graph Neural Networks with PyTorch & ...   1100             9
# 2                       How to Use ggplot2 in Python    767             5
#
#             publication        date
# 0  Towards Data Science  2019-05-30
# 1  Towards Data Science  2019-05-30
# 2  Towards Data Science  2019-05-30

# %%
medium['date']=medium['date'].astype('datetime64')

# %%
medium['month']=medium['date'].dt.month_name()

# %%
medium.head(3)
# Out:
#                                                title  claps  reading_time  \
# 0  A Beginner’s Guide to Word Embedding with Gens...    850             8
# 1  Hands-on Graph Neural Networks with PyTorch & ...   1100             9
# 2                       How to Use ggplot2 in Python    767             5
#
#             publication       date month
# 0  Towards Data Science 2019-05-30   May
# 1  Towards Data Science 2019-05-30   May
# 2  Towards Data Science 2019-05-30   May

# %%
#cat_month=CategoricalDtype(['Janaury','February','March','April','May','June','July','August','September','October','November','December'])

# %%
#medium['month']=medium['month'].astype(cat_month)

# %%
medium.dtypes
# Out:
# title                   object
# claps                    int64
# reading_time             int64
# publication             object
# date            datetime64[ns]
# month                   object
# dtype: object

# %%
plt.figure();

# %%
joyplot(data=medium[['reading_time','month']],by='month',figsize=(12,8),linecolor='green',color='firebrick',yrot=45);

# %%
joyplot(data=medium[['reading_time','claps','month']],by='month',column=['claps','reading_time'],figsize=(12,8),color=['firebrick','springgreen'],legend=True,alpha=0.86,yrot=45);
